# %% [markdown]
# # Run B / p-median
#
# Colab launcher. The actual logic lives in `scripts/` and `src/`.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# If running from a fresh Colab, clone the repo first.
# Replace YOUR_USERNAME with your GitHub username once the repo is uploaded.
# !git clone https://github.com/YOUR_USERNAME/llm-clustering-heuristics.git
# %cd llm-clustering-heuristics

# If you already uploaded/opened this repo in Colab, cd into it manually before continuing.
# !pwd

# %%
# !pip install -r requirements.txt

# %%
# Run the experiment.
# Real artifacts will be written to the artifact_base_dir set in configs/run_B_pmedian.yaml.
# !python scripts/run_unified_pipeline.py --config configs/run_B_pmedian.yaml
